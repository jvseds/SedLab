# %% [markdown]
# ## Bray-Curtis Dissimilarity Dendrogram

# %% [markdown]
# To cluster samples and empirically define and compare depositional environments, a Bray-Curtis dissimilarity analysis will be performed using grain size data and XRF data.

# %%
import numpy as np
import pandas as pd
from grainsize import BCD

# %%
sr19 = BCD(fname="./data-files/gs-files/sr19-gs-complete.csv")
# slice df to include only depths down to 261 cm
sr19.dataframe = sr19.dataframe[sr19.dataframe.index <= 261]
# compute Bray Curtis distances
sr19_dist = sr19.compute_BCD()
# compute the squareform
sr19_sf = sr19.compute_squareform()

# %%
sr19.plot_dendrogram(core_name="SR19P4")
# Out:
# (<Figure size 1000x800 with 1 Axes>,
#  <Axes: title={'center': 'Bray-Curtis Dissimilarity for SR19P4'}, xlabel='Dissimilarity', ylabel='Depth (cm)'>)

# %% [markdown]
# Preprocessing and plotting for SR21-P7

# %%
# SR21-P7 data
sr21 = BCD(fname="./data-files/gs-files/sr21-gs-complete.csv")
# compute Bray Curtis distances
sr21_dist = sr21.compute_BCD()
# compute the squareform
sr21_sf = sr21.compute_squareform()

# %%
sr21.plot_dendrogram(core_name="SR21P7")
# Out:
# (<Figure size 1000x800 with 1 Axes>,
#  <Axes: title={'center': 'Bray-Curtis Dissimilarity for SR21P7'}, xlabel='Dissimilarity', ylabel='Depth (cm)'>)
